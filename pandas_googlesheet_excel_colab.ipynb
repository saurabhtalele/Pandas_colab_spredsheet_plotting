# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabhtalele/Pandas_colab_spredsheet_plotting/blob/main/pandas_googlesheet_excel_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#taking authorization from colab
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# Taking authorization from **colab** and connect to spread sheet

# %%
import gspread
from oauth2client.client import GoogleCredentials
 
gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
#opening file
wb = gc.open('PDC 1643 saurabh ')

# %%
import pandas as pd
wb
# Out:
# <Spreadsheet 'PDC 1643 saurabh ' id:1Rp5jSqHj1BDig60tbNIJtUVfBjtMx2XPapGbFLN6jYo>

# %%
#Reading rows
rows=wb.sheet1.get_all_values()

# %%
#converting all rows aas dataframe in pandas
df=pd.DataFrame.from_records(rows)
df
# Out:
#       0  ...                                      5
# 0        ...                             Efficiency
# 1    10  ...  Efficiency @ AOA 2, Alpha 16, Beta 12
# 2    20  ...  Efficiency @ AOA 2, Alpha 16, Beta 12
# 3    30  ...  Efficiency @ AOA 2, Alpha 16, Beta 12
# 4    40  ...  Efficiency @ AOA 2, Alpha 16, Beta 12
# ..  ...  ...                                    ...
# 56   60  ...  Efficiency @ AOA 2, Alpha 16, Beta 17
# 57   70  ...  Efficiency @ AOA 2, Alpha 16, Beta 17
# 58   80  ...  Efficiency @ AOA 2, Alpha 16, Beta 17
# 59   90  ...  Efficiency @ AOA 2, Alpha 16, Beta 17
# 60  100  ...  Efficiency @ AOA 2, Alpha 16, Beta 17
#
# [61 rows x 6 columns]

# %% [markdown]
# # ***CREATING SEPERATED workflow in google drive ***

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Now working folder and colab file .ipynb in same folder i.e every colab file  is generated in colab notbook so we have just drag and drop our .ipynb file from that folder to pandas using GUI of drive

# %%
import os 

# Set your working directory to a folder in your Google Drive. This way, if your notebook times out,
# your files will be saved in your Google Drive!

# the base Google Drive directory
root_dir = "/content/drive/My Drive/"

# choose where you want your project files to be saved
project_folder = "Colab Notebooks/Pandas/"

def create_and_set_working_directory(project_folder):
  # check if your project folder exists. if not, it will be created.
  if os.path.isdir(root_dir + project_folder) == False:
    os.mkdir(root_dir + project_folder)
    print(root_dir + project_folder + ' did not exist but was created.')

  # change the OS to use your project folder as the working directory
  os.chdir(root_dir + project_folder)

  # create a test file to make sure it shows up in the right place
  # !touch 'new_file_in_working_directory.txt'
  print('\nYour working directory was changed to ' + root_dir + project_folder + \
        "\n\nAn empty text file was created there. You can also run !pwd to confirm the current working directory." )

create_and_set_working_directory(project_folder)
# Out:
# Your working directory was changed to /content/drive/My Drive/Colab Notebooks/Pandas/
#
# An empty text file was created there. You can also run !pwd to confirm the current working directory.

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/Pandas'

# %% [markdown]
# # SAving that google spredsheet into our Pandas folder in google drive (/content/drive/My Drive/Colab Notebooks/Pandas)

# %%
# NOw pandas have three file .txt,.xls.ipynb
PDC_1643_saurabh='PDC_1643_saurabh.xlsx'
df.to_excel(PDC_1643_saurabh)

# %% [markdown]
# # ***here we have added names of heder like test,velocity which aran't there before by directly opening and wrting it to .xlxs file and we doest want first rows as it is generated by pands before so we skipped it.***

# %%
# opening now PDC_1643_saurabh
df1=pd.read_excel("PDC_1643_saurabh.xlsx",skiprows=1)
df1
# Out:
#     tests  velocity  ...      FL/FD                             Efficiency
# 0       1        10  ...  11.397533  Efficiency @ AOA 2, Alpha 16, Beta 12
# 1       2        20  ...  11.850229  Efficiency @ AOA 2, Alpha 16, Beta 12
# 2       3        30  ...  12.071781  Efficiency @ AOA 2, Alpha 16, Beta 12
# 3       4        40  ...  12.217994  Efficiency @ AOA 2, Alpha 16, Beta 12
# 4       5        50  ...  12.312554  Efficiency @ AOA 2, Alpha 16, Beta 12
# 5       6        60  ...  12.394020  Efficiency @ AOA 2, Alpha 16, Beta 12
# 6       7        70  ...  12.454315  Efficiency @ AOA 2, Alpha 16, Beta 12
# 7       8        80  ...  12.502892  Efficiency @ AOA 2, Alpha 16, Beta 12
# 8       9        90  ...  12.551850  Efficiency @ AOA 2, Alpha 16, Beta 12
# 9      10       100  ...  12.588006  Efficiency @ AOA 2, Alpha 16, Beta 12
# 10     11        10  ...  11.301158  Efficiency @ AOA 2, Alpha 16, Beta 13
# ...

# %% [markdown]
# # ***plotting***

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array(df1['CL/CD'])
#plotting is take place like first row all column ,so data reshaped in 10*6 , there are 60 test 6 column for different angles of wings 10  and for 10 different velocity
y= np.reshape(y,(10,6),order='F')
x=list(np.arange(10,110,10))
y
# Out:
# array([[11.39753286, 11.30115809, 11.12241537, 11.01475288, 10.74632274,
#         10.6332811 ],
#        [11.8502291 , 11.72381685, 11.52896624, 11.39832239, 11.11287325,
#         10.97867458],
#        [12.07178164, 11.93931016, 11.73015188, 11.58596116, 11.30013703,
#         11.14929222],
#        [12.21799386, 12.07329218, 11.85938753, 11.70835636, 11.39739637,
#         11.25383016],
#        [12.31255408, 12.16250191, 11.95377699, 11.79135039, 11.48212585,
#         11.32725159],
#        [12.3940206 , 12.23751844, 12.02253065, 11.85475503, 11.5411931 ,
#         11.38681385],
#        [12.45431535, 12.29833735, 12.07997883, 11.9087172 , 11.59122322,
#         11.42986723],
#        [12.50289279, 12.34661572, 12.12685048, 11.95101954, 11.63019538,
#         11.46668674],
#        [12.55185072, 12.38467308, 12.17438386, 11.98794181, 11.66899013,
#         11.50277981],
#        [12.58800598, 12.42570858, 12.20834147, 12.01890596, 11.69097746,
#         11.52895261]])

# %%
lines=plt.plot(x,y)
plt.ylabel("cl/cd")
plt.xlabel("velocity")
plt.legend(lines[:1], ['Efficiency @ AOA 2, Alpha 16, Beta 12']);

plt.show()
